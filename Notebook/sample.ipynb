# %%
import pandas as pd

# %%
df = pd.read_csv('./data/dailyclimate.csv')

# %%
df.sample(10)
# Out:
#         Unnamed: 0        Date     District  Latitude  Longitude  Precip  \
# 432429      432429  1994-12-28     Lalitpur      27.6       85.3    0.00
# 596391      596391  2014-12-01  Okhaldhunga      27.3       86.5    0.00
# 605054      605054  1999-08-21        Palpa      27.9       83.5    2.57
# 832660      832660  1998-10-27      Tanahun      28.0       84.1    0.00
# 702688      702688  1993-12-16       Salyan      28.4       82.1    0.00
# 796872      796872  2017-10-31      Sunsari      26.6       87.1    1.40
# 648257      648257  2000-12-04       Rasuwa      28.1       85.3    0.00
# 230077      230077  1986-12-14       Dolkha      27.6       86.2    1.38
# 747700      747700  2000-03-14      Sarlahi      26.9       85.5    0.13
# 81136        81136  2008-02-25         Bara      27.2       85.0    0.00
#
#         Pressure  Humidity_2m  RH_2m  Temp_2m  ...  TempRange_2m  \
# 432429     84.37         2.09  21.43    11.11  ...         11.44
# ...

# %%
got_para = ['Longitude', 'Latitude', 'Temp_2m', 'MaxTemp_2m', 'MinTemp_2m', 'Pressure', 'Humidity_2m', 'WindSpeed_10m']
use_df = df[got_para]
use_df
# Out:
#         Longitude  Latitude  Temp_2m  MaxTemp_2m  MinTemp_2m  Pressure  \
# 0            83.2      27.9    13.89       20.82        9.94     93.51
# 1            83.2      27.9    13.84       20.70        9.54     93.59
# 2            83.2      27.9    14.33       20.71       10.78     93.55
# 3            83.2      27.9    13.82       20.43       10.02     93.49
# 4            83.2      27.9    13.76       19.62        9.08     93.49
# ...           ...       ...      ...         ...         ...       ...
# 883123       86.5      26.9    11.13       17.98        6.97     95.52
# 883124       86.5      26.9    10.56       18.52        5.34     95.73
# 883125       86.5      26.9    11.51       19.34        7.04     95.76
# 883126       86.5      26.9    12.47       20.03        7.83     95.84
# 883127       86.5      26.9    14.77       21.96       10.28     95.93
#
#         Humidity_2m  WindSpeed_10m
# 0              4.81           1.89
# 1              4.94           1.72
# ...

# %%
use_df.sample(15)
# Out:
#         Longitude  Latitude  Temp_2m  MaxTemp_2m  MinTemp_2m  Pressure  \
# 252074       82.9      29.0    -2.63        5.17       -8.01     62.06
# 339428       87.9      26.7    25.28       32.45       18.45     92.58
# 409654       84.0      28.2    17.16       19.59       15.41     78.24
# 405158       84.0      28.2    17.29       23.68       12.54     78.25
# 599721       83.5      27.9    12.61       20.53        7.96     93.34
# 679674       82.4      28.6     5.51       11.56        1.52     75.02
# 707936       82.1      28.4    26.39       34.85       17.79     88.64
# 514516       82.1      29.5     4.04       10.60       -0.60     61.83
# 181205       80.6      29.9     5.28       11.94        1.02     74.08
# 160722       82.4      28.0     9.28       15.67        5.32     87.16
# 354669       82.3      29.3     4.22       11.71       -1.23     75.22
# 525895       82.1      29.5    -1.96        5.02       -6.10     61.82
# ...

# %%
for no in range(0,61):
    if df.District
# Out:
# 0         Arghakhanchi
# 1         Arghakhanchi
# 2         Arghakhanchi
# 3         Arghakhanchi
# 4         Arghakhanchi
#               ...
# 883123        Udayapur
# 883124        Udayapur
# 883125        Udayapur
# 883126        Udayapur
# 883127        Udayapur
# Name: District, Length: 883128, dtype: object

# %%
unique_districts = df["District"].unique()
print(unique_districts)
# Out:
# ['Arghakhanchi' 'Baglung' 'Baitadi' 'Bajang' 'Banke' 'Bara' 'Bardiya'
#  'Bhaktapur' 'Chitawan' 'Dadeldhura' 'Dailekh' 'Dang' 'Darchula' 'Dhading'
#  'Dhankuta' 'Dhanusa' 'Dolkha' 'Dolpa' 'Doti' 'Gorkha' 'Gulmi' 'Humla'
#  'Ilam' 'Jhapa' 'Jumla' 'Kabhre' 'Kailali' 'Kanchanpur' 'Kaski'
#  'Kathmandu' 'Lalitpur' 'Lamjung' 'Mahottari' 'Makwanpur' 'Manang'
#  'Morang' 'Mugu' 'Mustang' 'Myagdi' 'Nawalparasi' 'Nuwakot' 'Okhaldhunga'
#  'Palpa' 'Panchther' 'Parbat' 'Rasuwa' 'Routahat' 'Rukum' 'Rupandehi'
#  'Salyan' 'Sankhuwasabha' 'Saptari' 'Sarlahi' 'Sindhuli' 'Solukhumbu'
#  'Sunsari' 'Surkhet' 'Syangja' 'Tanahun' 'Taplejung' 'Terhathum'
#  'Udayapur']

# %%
uniuq_value = df[['District', 'Latitude', 'Longitude']].unique()
print(uniuq_value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17580\3951424161.py in ?()
# ----> 1 uniuq_value = df[['District', 'Latitude', 'Longitude']].unique()
#       2 print(uniuq_value)
#
# c:\Users\9849i\OneDrive\Documents\Bhuwan\Python Scripts\learn_python\temp_new\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df[['District', 'Latitude', 'Longitude']]
# Out:
#             District  Latitude  Longitude
# 0       Arghakhanchi      27.9       83.2
# 1       Arghakhanchi      27.9       83.2
# 2       Arghakhanchi      27.9       83.2
# 3       Arghakhanchi      27.9       83.2
# 4       Arghakhanchi      27.9       83.2
# ...              ...       ...        ...
# 883123      Udayapur      26.9       86.5
# 883124      Udayapur      26.9       86.5
# 883125      Udayapur      26.9       86.5
# 883126      Udayapur      26.9       86.5
# 883127      Udayapur      26.9       86.5
#
# [883128 rows x 3 columns]

# %%
unique_distri = df.drop_duplicates(subset="District")[["District", "Latitude", "Longitude"]]

# Reset index (optional, for a clean output)
unique_distri = unique_distri.reset_index(drop=True)
pd.set_option('display.max_rows', None)
# Print the result
print(unique_distri)
# Out:
#          District  Latitude  Longitude
# 0    Arghakhanchi      27.9       83.2
# 1         Baglung      28.3       83.6
# 2         Baitadi      29.5       80.5
# 3          Bajang      29.6       81.2
# 4           Banke      28.1       81.7
# 5            Bara      27.2       85.0
# 6         Bardiya      28.3       81.4
# 7       Bhaktapur      27.7       85.5
# 8        Chitawan      27.7       84.4
# 9      Dadeldhura      29.3       80.6
# 10        Dailekh      28.8       81.7
# 11           Dang      28.0       82.4
# 12       Darchula      29.9       80.6
# 13        Dhading      27.7       85.2
# 14       Dhankuta      27.0       87.3
# 15        Dhanusa      26.7       85.9
# 16         Dolkha      27.6       86.2
# 17          Dolpa      29.0       82.9
# 18           Doti      29.2       80.9
# 19         Gorkha      28.0       84.6
# 20          Gulmi      28.1       83.2
# 21          Humla      30.0       81.8
# 22           Ilam      26.9       87.9
# ...

# %%
unique_dist = pd.(unique_distri)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 unique_dist = pd.to_DataFrame(unique_distri)
#
# AttributeError: module 'pandas' has no attribute 'to_DataFrame'
